# %%
import csv
import requests
from bs4 import BeautifulSoup
import pandas as pd
import tweepy
from KEYS.twitter_keys import API_KEY, API_SECRET_KEY, CLIENT_KEY, CLIENT_SECRET_KEY, BEARER_TOKEN, ACCESS_TOKEN, ACCESS_TOKEN_SECRET
import json
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 from bs4 import BeautifulSoup
#       4 import pandas as pd
# ----> 5 import tweepy
#       6 from KEYS.twitter_keys import API_KEY, API_SECRET_KEY, CLIENT_KEY, CLIENT_SECRET_KEY, BEARER_TOKEN, ACCESS_TOKEN, ACCESS_TOKEN_SECRET
#       7 import json
#
# ModuleNotFoundError: No module named 'tweepy'

# %%
# URL della pagina con i ticker delle aziende nello FTSE MIB
url = 'https://it.marketscreener.com'
url_ind = url + '/quotazioni/indice/FTSE-MIB-INDEX-121229431/composizione/'
response_ind = requests.get(url_ind)
soup_ind = BeautifulSoup(response_ind.content, 'html.parser')
table = soup_ind.find('table', {'id': 'ALNI1'})
rows = table.find_all('tr')

# %%
def get_ticker(link):
    url_tick = url + link
    response_tick = requests.get(url_tick)
    soup_tick = BeautifulSoup(response_tick.content, 'html.parser')
    info = soup_tick.find_all('div',{'class', 'bc_pos'})[0].find_all('span', {'class':'fvTitleInfo'})
    return info[0].text.strip(), info[1].text.strip()

# %%
d = {'ISIN':[], 'Ticker':[], 'Societa':[],'Peso':[]}

for i in range(1, len(rows)):
    row = rows[i]
    td = row.find_all('td')
    link = td[1].find('a')['href'].strip()
    ticker, isin = get_ticker(link)
    
    d['ISIN'].append(isin)
    d['Ticker'].append(ticker)
    d['Societa'].append(td[1].text.strip())
    d['Peso'].append(td[7].text.strip())

# %%
import pandas as pd

df = pd.DataFrame(d)
df
# Out:
#             ISIN Ticker                    Societa    Peso
# 0   IT0003128367   ENEL                ENEL S.P.A.  10.78%
# 1   IT0000072618    ISP     INTESA SANPAOLO S.P.A.   9.26%
# 2   IT0003132476    ENI                    ENI SPA   8.31%
# 3   NL00150001Q9  STLAM            STELLANTIS N.V.    7.3%
# 4   IT0005239360    UCG           UNICREDIT S.P.A.   6.96%
# 5   NL0011585146   RACE               FERRARI N.V.   6.59%
# 6   IT0000062072      G                   GENERALI   6.22%
# 7   NL0000226223    STM    STMICROELECTRONICS N.V.   5.88%
# 8   NL0010545661   CNHI        CNH INDUSTRIAL N.V.   4.09%
# 9   IT0003153415    SRG                SNAM S.P.A.   2.81%
# 10  IT0004965148   MONC             MONCLER S.P.A.   2.77%
# 11  IT0003242622    TRN               TERNA S.P.A.   2.71%
# 12  IT0000072170    FBK          FINECOBANK S.P.A.   2.58%
# 13  IT0004176001    PRY            PRYSMIAN S.P.A.   2.53%
# 14  LU0156801721    TEN               TENARIS S.A.   2.12%
# 15  IT0000062957     MB          MEDIOBANCA S.P.A.   1.57%
# 16  NL0015435975    CPR  DAVIDE CAMPARI-MILANO N..   1.32%
# 17  IT0005218380   BAMI           BANCO BPM S.P.A.   1.26%
# 18  IT0003796171    PST      POSTE ITALIANE S.P.A.   1.15%
# 19  IT0005366767   NEXI                 NEXI S.P.A   1.12%
# 20  IT0003828271    REC                  RECORDATI   1.04%
# 21  IT0004056880    AMP            AMPLIFON S.P.A.   0.96%
# 22  IT0001078911     IP     INTERPUMP GROUP S.P.A.   0.94%
# 23  IT0005090300    INW               INWIT S.P.A.   0.91%
# 24  IT0003856405    LDO            LEONARDO S.P.A.   0.89%
# 25  IT0003492391    DIA            DIASORIN S.P.A.   0.77%
# 26  IT0005211237     IG             ITALGAS S.P.A.   0.71%
# 27  IT0003497168    TIT      TELECOM ITALIA S.P.A.   0.64%
# 28  IT0003261697    AZM      AZIMUT HOLDING S.P.A.   0.62%
# 29  IT0000066123    BPE          BPER BANCA S.P.A.   0.56%
# 30  IT0005278236   PIRC        PIRELLI & C. S.P.A.   0.55%
# 31  IT0004810054    UNI       UNIPOL GRUPPO S.P.A.   0.54%
# 32  IT0001250932    HER                HERA S.P.A.   0.54%
# 33  IT0001233417    A2A                 A2A S.P.A.   0.52%
# 34  IT0004776628   BMED    BANCA MEDIOLANUM S.P.A.   0.52%
# 35  IT0001031084    BGN      BANCA GENERALI S.P.A.   0.49%
# 36  IT0001157020    ERG                 ERG S.P.A.   0.44%
# 37  IT0001347308    BZU        BUZZI UNICEM S.P.A.   0.43%
# 38  IT0005495657    SPM                 SAIPEM SPA   0.32%
# 39  NL0015000LU4    IVG           IVECO GROUP N.V.    0.3%

# %%
import pandas as pd
table=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
df = table[0]
df.to_csv('SP500-Info.csv')
df.to_csv("SP500-Symbols.csv", columns=['Symbol'])

# %%
giornali = {
    'Testata':
        [
            "Il Sole 24 Ore",
            "Italia Oggi",
            "MF Milano Finanza",
            "L'Avvisatore Marittimo",
            "Il Globo",
            "Il Sole",
            "Borsa e mercati",
            "Verità e affari"
        ],
    'Link':
        [
            "https://www.ricerca24.ilsole24ore.com/?cmd=static&chId=30&path=/search/search_engine.jsp&field=Titolo|Testo&orderBy=data+desc&chId=30&keyWords="&ticker&"&pageNumber=1&pageSize=100&fromDate=01/02/2018&toDate=01/02/2023&filter=all#"
            ""
            ""
            ""
        ],     
}

# %%
def get_sole24ore(societa):
    url = "https://www.ricerca24.ilsole24ore.com/?cmd=static&chId=30&path=/search/search_engine.jsp&field=Titolo|Testo&orderBy=data+desc&chId=30&keyWords="&societa.replace(" ","+")&"&pageNumber=1&pageSize=100&fromDate=01/02/2018&toDate=01/02/2023&filter=all#"
    url_tick = url + link
    response_tick = requests.get(url_tick)
    soup_tick = BeautifulSoup(response_tick.content, 'html.parser')
    info = soup_tick.find_all('div',{'class', 'bc_pos'})[0].find_all('span', {'class':'fvTitleInfo'})

# %%
societa = "Intesa Sanpaolo S.p.a."
societa = societa.replace(' ',"+")
url = "https://www.ricerca24.ilsole24ore.com/?cmd=static&chId=30&path=/search/search_engine.jsp&field=Titolo|Testo&orderBy=data+desc&chId=30&keyWords="+societa+"&pageNumber=1&pageSize=10&fromDate=01/02/2018&toDate=01/02/2023&filter=all#"

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
# inserisci le tue chiavi API e OAuth
consumer_key = API_KEY
consumer_secret = API_SECRET_KEY
access_token = ACCESS_TOKEN
access_token_secret = ACCESS_TOKEN_SECRET
bearer_token = BEARER_TOKEN


search_url = "https://api.twitter.com/2/tweets/search/recent"

# Optional params: start_time,end_time,since_id,until_id,max_results,next_token,
# expansions,tweet.fields,media.fields,poll.fields,place.fields,user.fields

def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2RecentSearchPython"
    return r

def connect_to_endpoint(url, params):
    response = requests.get(url, auth=bearer_oauth, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()

tickers = ['"$AAPL"', '"$MSFT.MI"']
for ticker in tickers:
    query_params = {'query': ticker, 'tweet.fields': 'author_id'}
    json_response = connect_to_endpoint(search_url, query_params)
    current_time = int(time.time())
    filename = f"data_{ticker}_{current_time}_{len(json_response)}.json"
    with open(filename, "w") as outfile:
        json.dump(json_response, outfile, indent=4, sort_keys=True)
